# %%
#Implement Binary tree

class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinaryTree:
    def __init__(self):
        self.root = None

    def add_node(self, value):
        node = Node(value)
        if self.root is None:
            self.root = node
        else:
            current = self.root
            while True:
                if value < current.value:
                    if current.left is None:
                        current.left = node
                        break
                    else:
                        current = current.left
                else:
                    if current.right is None:
                        current.right = node
                        break
                    else:
                        current = current.right

    def in_order_traversal(self, node):
        if node is not None:
            self.in_order_traversal(node.left)
            print(node.value)
            self.in_order_traversal(node.right)

    def pre_order_traversal(self, node):
        if node is not None:
            print(node.value)
            self.pre_order_traversal(node.left)
            self.pre_order_traversal(node.right)

    def post_order_traversal(self, node):
        if node is not None:
            self.post_order_traversal(node.left)
            self.post_order_traversal(node.right)
            print(node.value)

# %%
# Find height of a given tree

class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def height(node):
    if node is None:
        return 0
    else:
        left_height = height(node.left)
        right_height = height(node.right)

        # Return the maximum of the left and right subtree heights plus one
        return max(left_height, right_height) + 1

tree = Node(1)
tree.left = Node(2)
tree.right = Node(3)
tree.left.left = Node(4)
tree.left.right = Node(5)

print(height(tree)) 

# Output: 3
# Out:
# 3

# %%
# Perform Pre-order, Post-order, In-order traversal

# Pre-order Traversal

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def pre_order(root):
    if root is not None:
        print(root.data)
        pre_order(root.left)
        pre_order(root.right)

# Post-order Traversal

def post_order(root):
    if root is not None:
        post_order(root.left)
        post_order(root.right)
        print(root.data)

        
# In-order Traversal

def in_order(root):
    if root is not None:
        in_order(root.left)
        print(root.data)
        in_order(root.right)

# %%
# Function to print all the leaves in a given binary tree

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def print_leaves(root):
    if root is not None:
        if root.left is None and root.right is None:
            print(root.data)
        else:
            print_leaves(root.left)
            print_leaves(root.right)

# %%
# Implement BFS (Breath First Search) and DFS (Depth First Search)

from collections import deque

class Graph:
    def __init__(self, num_vertices):
        self.num_vertices = num_vertices
        self.adj_list = [[] for _ in range(num_vertices)]

    def add_edge(self, src, dest):
        self.adj_list[src].append(dest)

def bfs(graph, start):
    visited = [False] * graph.num_vertices
    queue = deque()
    queue.append(start)
    visited[start] = True

    while queue:
        node = queue.popleft()
        print(node, end=' ')

        for neighbor in graph.adj_list[node]:
            if not visited[neighbor]:
                queue.append(neighbor)
                visited[neighbor] = True

def dfs(graph, start):
    visited = [False] * graph.num_vertices
    dfs_util(graph, start, visited)

def dfs_util(graph, node, visited):
    visited[node] = True
    print(node, end=' ')

    for neighbor in graph.adj_list[node]:
        if not visited[neighbor]:
            dfs_util(graph, neighbor, visited)

# %%
# Find sum of all left leaves in a given Binary Tree

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def sum_left_leaves(root):
    if root is None:
        return 0

    if root.left is not None and root.left.left is None and root.left.right is None:
        return root.left.data + sum_left_leaves(root.right)

    return sum_left_leaves(root.left) + sum_left_leaves(root.right)

# %%
# Find sum of all nodes of the given perfect binary tree

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def sum_all_nodes(root):
    if root is None:
        return 0

    # The sum of all nodes in a perfect binary tree can be computed using the formula:
    # sum = (2^(height+1))-1, where height is the height of the tree
    height = get_height(root)
    sum_nodes = (2**(height+1)) - 1

    return sum_nodes

def get_height(root):
    if root is None:
        return -1
    else:
        return 1 + get_height(root.left)

# %%
# Count subtress that sum up to a given value x in a binary tree

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def count_subtrees_with_sum_x(root, x):
    if root is None:
        return 0

    count = 0
    count += count_subtrees_with_sum_x(root.left, x)
    count += count_subtrees_with_sum_x(root.right, x)

    if root.data == x:
        count += 1

    left_sum = get_subtree_sum(root.left)
    right_sum = get_subtree_sum(root.right)

    if left_sum + right_sum + root.data == x:
        count += 1

    return count

def get_subtree_sum(root):
    if root is None:
        return 0

    return root.data + get_subtree_sum(root.left) + get_subtree_sum(root.right)

# %%
# Find maximum level sum in Binary Tree 

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def max_level_sum(root):
    if root is None:
        return 0

    queue = [root]
    max_sum = float('-inf')
    max_level = 0
    level = 1

    while queue:
        level_sum = 0
        level_size = len(queue)

        for i in range(level_size):
            node = queue.pop(0)
            level_sum += node.data

            if node.left is not None:
                queue.append(node.left)

            if node.right is not None:
                queue.append(node.right)

        if level_sum > max_sum:
            max_sum = level_sum
            max_level = level

        level += 1

    return max_level

# %%
# Print the nodes at odd levels of a tree

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def print_nodes_at_odd_levels(root):
    if root is None:
        return

    queue = [root]
    level = 1

    while queue:
        level_size = len(queue)

        for i in range(level_size):
            node = queue.pop(0)

            if level % 2 != 0:
                print(node.data)

            if node.left is not None:
                queue.append(node.left)

            if node.right is not None:
                queue.append(node.right)

        level += 1
